# %% [markdown]
# # **IRWA_LAB_PART_3**

# %% [markdown]
# **Ranking score:**
# Given a query, we want to get the top-20 documents related to the query.
#
# **GOAL:**
# Find all the documents that contain all the words in the query and sort them by
# their relevance with regard to the query.

# %% [markdown]
# # **0. LOADINGS**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import nltk
nltk.download('stopwords')

from collections import defaultdict
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import collections
from numpy import linalg as la
import json
import string
import re
import pandas as pd
from collections import Counter
import math
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
docs_path = '/content/drive/MyDrive/RIAW/IRWA_data_2024/data/farmers-protest-tweets.json'
with open(docs_path) as fp:
    lines = fp.readlines()
lines = [l.strip().replace(' +', ' ') for l in lines]

tweets = [json.loads(line.strip()) for line in lines]

# %%
print("Total number of tweets : {}".format(len(tweets)))
# Out:
# Total number of tweets : 117407

# %%
evaluation_file_path = '/content/drive/MyDrive/RIAW/IRWA_data_2024/data/evaluation.csv'

df_evaluation = pd.read_csv(evaluation_file_path, sep=";")
df_evaluation.head()
# Out:
#       docId  query_id  label
# 0   doc_156       1.0    0.0
# 1  doc_1039       1.0    0.0
# 2  doc_1047       1.0    1.0
# 3  doc_1685       1.0    0.0
# 4  doc_2100       1.0    1.0

# %% [markdown]
# ## **Bidirectional Mapping for the tweet’s Ids with the document ids for evaluation**

# %%
docs_path_map = '/content/drive/MyDrive/RIAW/IRWA_data_2024/data/tweet_document_ids_map.csv'

df = pd.read_csv(docs_path_map)


doc_to_tweet_map = dict(zip(df['docId'], df['id']))  #map doc to tweet id

tweet_to_doc_map = dict(zip(df['id'], df['docId']))  #map tweet_id to doc


doc_id = 'doc_0'
tweet_id = doc_to_tweet_map.get(doc_id)
print(f"doc_id {doc_id} have id {tweet_id}")


doc_id_10 = tweet_to_doc_map.get(1364505314586951680)
print(f"doc_id {doc_id_10} have id {1364505314586951680}")
# Out:
# doc_id doc_0 have id 1364506249291784198
# doc_id doc_10 have id 1364505314586951680

# %% [markdown]
# # **1. SCORINGS**

# %% [markdown]
# ## **TF-IDF + Cosine Similarity**

# %% [markdown]
# ### **Propose Test Queries**

# %%
test_queries = ["Who supports indian law",
                "Impact of government policies on farmers"]

# %% [markdown]
# ### **TF-IDF**

# %%
def build_terms(line):

    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))

    line = re.sub(r"http\S+|www\S+|https\S+", '', line, flags=re.MULTILINE)  #remove URLs

    line = line.lower() #lowercase

    tokens = line.split() #tokenize


    processed_tokens = []
    for token in tokens:

        if token.startswith('#'):
            processed_tokens.append(token) #keep hasthags exactly as they are
        else:
            token = token.translate(str.maketrans('', '', string.punctuation)) #remove punctuations

            if token and token not in stop_words: #eliminate the stopwords
                stemmed_token = stemmer.stem(token) #stemming
                processed_tokens.append(stemmed_token)

    return processed_tokens

# %%
def create_inverted_index_tfidf(tweets, tweet_to_doc_map):
    """
    Implement the inverted index and compute tf, df, and idf.

    Returns:
    index - the inverted index containing terms as keys and the corresponding list of documents these keys appear in (and the positions) as values.
    tf - normalized term frequency for each term in each document
    df - number of documents each term appears in
    idf - inverse document frequency of each term
    """

    index = defaultdict(list)
    tf = defaultdict(list)
    df = defaultdict(int)
    idf = defaultdict(float)

    num_documents = len(set(tweet_to_doc_map.values()))

    for tweet in tweets:
        tweet_id = tweet['id']
        doc_id = tweet_to_doc_map.get(tweet_id)

        if doc_id is not None:
            terms = build_terms(tweet['content'])
            current_doc_index = defaultdict(list)

            # Create current document index
            for position, term in enumerate(terms):
                current_doc_index[term].append(position)

            # Normalize term frequencies
            norm = math.sqrt(sum(len(postings) ** 2 for postings in current_doc_index.values()))

            for term, postings in current_doc_index.items():
                tf_val = np.round(len(postings) / norm, 4)
                if doc_id not in index[term]:  # Avoid duplicates
                    index[term].append((doc_id, postings))
                    tf[term].append(tf_val)
                    df[term] += 1

    # Compute IDF
    for term in df:
        idf[term] = np.round(np.log(float(num_documents) / df[term]), 4)

    return index, tf, df, idf

# %%
from collections import defaultdict, Counter
import numpy.linalg as la

def rank_documents(query, docs, index, idf, tf):
    """
    Perform the ranking of the results of a search based on the tf-idf weights.

    Returns:
    List of ranked documents along with their scores
    """

    # Process query into terms and initialize vectors
    query_terms = build_terms(query)
    query_vector = [0] * len(query_terms)
    doc_vectors = defaultdict(lambda: [0] * len(query_terms))

    # Count term frequency in query and normalize
    query_terms_count = Counter(query_terms)
    query_norm = la.norm([query_terms_count[term] for term in query_terms])

    # Build the query vector and each document vector
    for term_idx, term in enumerate(query_terms):
        if term in index:
            # Calculate the normalized term frequency for the query
            query_vector[term_idx] = (query_terms_count[term] / query_norm) * idf.get(term, 0)

            # Update document vectors with term frequencies and normalize
            for doc_idx, (doc, postings) in enumerate(index[term]):
                if doc in docs:
                    tf_norm = tf[term][doc_idx]  # Already normalized in tf calculation
                    doc_vectors[doc][term_idx] = tf_norm * idf[term]

    # Calculate normalized scores for each document
    doc_scores = []
    for doc, doc_vec in doc_vectors.items():
        doc_norm = la.norm(doc_vec)
        if doc_norm != 0:
            normalized_score = np.dot(doc_vec, query_vector) / doc_norm  # Normalize with document norm
            doc_scores.append([normalized_score, doc])

    # Sort documents by their relevance scores in descending order
    doc_scores.sort(reverse=True, key=lambda x: x[0])

    # Return ordered documents and their scores
    return [doc for _, doc in doc_scores], doc_scores

# %%
inv_index_tfidf, tf, df, idf = create_inverted_index_tfidf(tweets, tweet_to_doc_map)

# %%
docs = list(set(doc for postings in inv_index_tfidf.values() for doc, _ in postings)) # Extract a unique list of document IDs (doc_id) from the inverted index

# %% [markdown]
# ### **Ranking with Tf-idf + Cosine Similarity**

# %%
# Iterate over each test query
for query in test_queries:
    # Call the rank_documents function to get the ranked documents and their scores
    results, scores = rank_documents(query, docs, inv_index_tfidf, idf, tf)

    # Print the full rankings
    print(f"Ranking for query '{query}':\n")

    # Print the results (document ID, tweet ID, and content) for the top 20 documents
    for result in results[:20]:
        # Find the score corresponding to the document
        score = next((score for score, doc in scores if doc == result), None)
        # Find the content of the tweet corresponding to the document ID
        tweet_content = next((tweet['content'] for tweet in tweets if tweet['id'] == doc_to_tweet_map.get(result)), "No content available")

        print(f"Doc ID: {result}, Tweet ID: {doc_to_tweet_map.get(result)}, Score: {score}")
        print(f"Content: {tweet_content}\n")

    print("\n")
# Out:
# Ranking for query 'Who supports indian law':
#
# Doc ID: doc_9681, Tweet ID: 1363444730474885128, Score: 2.7320568625122
# Content: @MEAIndia @DrSJaishankar Will you also be shooting off an angry letter to the 87 America farmers union supporting Indian's farmers in their struggle against the corporate-benefiting black laws?
#
# https://t.co/atc5QCaUNH
#
# #FarmersProtest #MSPLawForAllCrops
#
# Doc ID: doc_10497, Tweet ID: 1363348220445925378, Score: 2.7320568625122
# Content: 87 farmer organisations and food justice groups in the United States delivered a solidarity statement in support of Indian farmers' protests against the new farm laws.
#
# #FarmersProtest https://t.co/PYklCc7xUI
#
# Doc ID: doc_3390, Tweet ID: 1364130568808595456, Score: 2.7320568625121995
# Content: We can be proud of Ajit Singh Ji and the #FarmersProtest in 1907 whilst also supporting a peaceful and pragmatic end to the current protest.
#
# Remember, the Indian Supreme Court has already intervened:
# - Laws on hold
# - Offer to mediate
#
# #Pagdi_Sambhal_Jatta https://t.co/SpDD7gM4lZ
#
# Doc ID: doc_3563, Tweet ID: 1364110026361745411, Score: 2.7320568625121995
# Content: Just curious... how much money does the Indian govt have to keep paying people to show up in support of BJP? How many "farmers" have you already paid to say farm laws are good? Didnt know India had a budget for this🤡🤡 #FarmersProtest #Pagdi_Sambhal_Jatta #FarmersProtests https://t.co/KZ7jiXzAYA
#
# Doc ID: doc_5074, Tweet ID: 1363994816162455559, Score: 2.7320568625121995
# Content: Indian farmers protest is an ongoing protest against three farm acts which were passed by the Parliament of India in Sept 2020. Farmer unions and their reps have demanded that the laws be repealed and have stated that they will not accept a compromise support #FarmersProtest
#
# Doc ID: doc_6038, Tweet ID: 1363837054052933632, Score: 2.7320568625121995
# Content: The Indian government is lying to the people by giving the #FarmersProtest a separatist spin because it's easier to gain support that way than to admit that these laws will be beneficial to private entities looking to expand in agriculture due to the economies of scale (6/6)
#
# Doc ID: doc_8259, Tweet ID: 1363624819636469769, Score: 2.7320568625121995
# Content: Thank you @ABC, US farmer unions.
# Thank you for supporting the farmers protesting the draconian laws forced upon Indian farmers
# #FarmersProtests #farmersprotest #MSPLawForAllCrops #NoFarmersNoFood https://t.co/oOweacZlGl
#
# Doc ID: doc_13857, Tweet ID: 1362992216130670593, Score: 2.7320568625121995
# Content: #DPstopIntimidatingFarmers
#
# Intimidation is the Indian government unwritten #toolkit circulated to DP against the law of this land and #StandWithDishaRavi who is another victim of supporting #FarmersProtest
#
# Doc ID: doc_26704, Tweet ID: 1361839799120797699, Score: 2.7320568625121995
# Content: @BernieSanders Grassroots support of democracy is so important. Indian farmers r facing devastatingly corrupt neoliberal farm laws. while peacefully protesting Modi gov is inflicting gross #HumanRightsViolations. Danger to democracy in one country is danger everywhere. #FarmersProtest https://t.co/JmOWt7lhMw
#
# Doc ID: doc_27080, Tweet ID: 1361790334934470663, Score: 2.7320568625121995
# Content: Disha Ravi, co-founder of @FFFIndia, was arrested and charged with sedition for editing a Toolkit on how to support the #FarmersProtest.  A 2016 report by @hrw found that the Indian government has been using the broadly-defined sedition law to squash dissent. https://t.co/rTlAn2hOrM
#
# Doc ID: doc_27890, Tweet ID: 1361724205709066247, Score: 2.7320568625121995
# Content: Indian farmers are protesting new laws that will allow corporations to drive down the prices at which farmers sell produce. In return, they’re facing severe govt repression
# @mujerxsrising just put out a video in support of the #FarmersProtest—please watch:
# https://t.co/PWrkVKY4Nc
#
# Doc ID: doc_46574, Tweet ID: 1360125250378362882, Score: 2.7320568625121995
# Content: @Cristiano @Cristiano plz support farmers protest which is going on in India Delhi against farm laws Indian media is not covering the protest. They r spreading negativity only about protest #FarmersProtest https://t.co/Tm6tj9Pw4I
#
# Doc ID: doc_48371, Tweet ID: 1360042595729121281, Score: 2.7320568625121995
# Content: Indian farmers have been on the road since November last year, seeking repeal of three new farm laws and demanding minimum support prices for their produce.
# We need Mahapanchayats to poke the sleeping pseudo-nationalists.
# #MahapanchayatRevolution
# #FarmersProtest
#
# Doc ID: doc_42274, Tweet ID: 1360532532446392320, Score: 2.6086295163082984
# Content: In support of ongoing farmers protest against black laws imposed by indian government, we are meeting at Sandringham park to share our thoughts and there will be aerial display in the Auckland sky with slogan
# support indian farmer #FarmersProtest
# from 2.30pm to 4.30pm
#
# Doc ID: doc_46130, Tweet ID: 1360169174178222084, Score: 2.588815931854206
# Content: So if Rihanna tweets in support of the farmers, Indian cricketers/actors will tweet that our sovereignty is under attack but if US govt says they support the Farm laws, they stay silent. It is clear that they are just pawns of propaganda for the Modi government #FarmersProtest https://t.co/tL6G6AVRWc
#
# Doc ID: doc_29728, Tweet ID: 1361559428063977473, Score: 2.5885734877990028
# Content: #FarmersProtests
# Milk &amp; food: Indian villages support protesting farmers
#
# Small villages around #Delhi are supporting the tens of thousands of farmers encamped around the capital as they demand the repeal of new agriculture laws
#
# https://t.co/w6FBVG8hJI #FarmLaws #FarmersProtest https://t.co/72duGMYiBy
#
# Doc ID: doc_7834, Tweet ID: 1363671712798289922, Score: 2.580230973564624
# Content: @ZeeNews 60% of Indian Population either directly or indirectly support #FarmersProtest to repeal Kisan Laws to make a Reform Laws for incorporating MSP in 23 crops limiting stocking.
# Is not #ModiIgnoringFarmersDeaths &amp; focusing only in WB, Assam, TN, Kerala, Puduchery elections ? Now https://t.co/wmED3mYZyb
#
# Doc ID: doc_7856, Tweet ID: 1363670184372932608, Score: 2.5802309735646234
# Content: 60% of Indian Population either directly or indirectly support #FarmersProtest to repeal Kisan Laws to make a Reform Laws for incorporating MSP in 23 crops limiting stocking.
# Is not #ModiIgnoringFarmersDeaths &amp; focusing only in WB, Assam, TM, Kerala, Puduchery elections ? Now https://t.co/4cBNKv15jJ
#
# Doc ID: doc_6880, Tweet ID: 1363729863987847169, Score: 2.580230973564623
# Content: 60% Indian Kisan supporting #FarmersProtest for repealing Kisan Laws to make Kisan Reform Law for incorporating MSP in 23 crops limiting stocks.
#
# Is not #ModiIgnoringFarmersDeaths &amp; focusing only in WB, Assam, TN, Kerala, Puduchery ?
# What next when Modi Ji in Election only ? https://t.co/NOzDREtvRw
#
# Doc ID: doc_7727, Tweet ID: 1363678305690546177, Score: 2.580230973564623
# Content: The farmers are much more learned and aware of the impact of the three Black laws than the govt tries to portray.
#
# #FarmersProtest
# #ModiDontSellFarmers
# #modi_rojgaar_do https://t.co/xQTHKispY3
#
# Doc ID: doc_8024, Tweet ID: 1363663839510822913, Score: 3.0740797078150077
# Content: @theskindoctor13 Farmers don’t want to burn stubble. They’re stuck due to the govt flaking on their responsibilities. @rustyrockets digs into the deep seeded (no pun) issues impacting #FarmersProtest
# Must watch
# 👇🏽
# https://t.co/I81EibCk1r
#
# @theskindoctor13 -🖕learn the facts &amp; have some empathy.
#
# Doc ID: doc_13667, Tweet ID: 1363005466071076866, Score: 3.0740797078150077
# Content: Hope this will happen all over Indian.
#
# Impact of Farmers Protests on Muncipal Corporation Elections in Punjab 2021 https://t.co/ScKhkaVYDz via @amaanbali
#
# #SaveFarmers
# #FarmersProtest
#
# Doc ID: doc_21821, Tweet ID: 1362227632037888000, Score: 3.0740797078150077
# Content: Original Reporting | BJP Routed In Punjab Municipal Elections As #FarmersProtest Impacts Electoral Fortunes, from @amaanbali
#
# “We never voted during municipal elections but this time I told my sons and daughters to vote for the sake of farmers."
#
# https://t.co/GtgJeUn6bE
#
# Doc ID: doc_31138, Tweet ID: 1361462903719690240, Score: 3.0740797078150077
# Content: #FarmersProtest
#  #IndiaBeingSilenced yes speak up president @POTUS and vp @KamalaHarris  this is not a Sikh vs india issue, it’s a farmers and each person who wants food vs Modi issue which will have global impacts if no one stands up to the bully. https://t.co/g1eez1Rwus
#
# Doc ID: doc_32147, Tweet ID: 1361346393030463488, Score: 3.0740797078150077
# Content: @RanaAyyub @POTUS @KamalaHarris We all must amplify their voices! She spoke up because Farmers feed all. This impacts all. If you are today, have an opinion! #IndiaBeingSilenced #FarmersProtest
#
# Doc ID: doc_41864, Tweet ID: 1360580739440414721, Score: 3.0740797078150077
# Content: @saahilmenghani this is being done to distract and divert attention from the impact of farmers protests and to drag India back into hindu v/s muslim, since WB elections are around the corner.
#
# #FarmersProtest   #RepealOnlyWayAhead
#
# Doc ID: doc_42639, Tweet ID: 1360502301790621699, Score: 3.0740797078150077
# Content: Bihar scrapped APMC Act, mandi system 14 years ago.
#
# Govt doesn’t give guaranteed MSP
# So allowing corporate to exploit to the max
#
# NO FINANCIAL PROTECTION
# NO LEGAL PROTECTION
#
# This will impact future of farmer &amp;consumers
#
# #RepealOnlyWayAhead
# #FarmersProtest https://t.co/LzmwOFcgB3
#
# Doc ID: doc_11290, Tweet ID: 1363278349683064833, Score: 3.0740797078150073
# Content: Russell Brand explains corporate takeover and impact on Indian farmers! Not pretty!! #FarmersProtest
#
# https://t.co/n4Ci3eGVhN
#
# Doc ID: doc_12293, Tweet ID: 1363118084828012546, Score: 3.0740797078150073
# Content: The first image is the way farmers ensured public is not impacted during rail roko &amp; 2nd is BJP goons  rail roko. #FarmersProtest @INCIndia @srivatsayb @Pawankhera https://t.co/6JnLGoZiFs
#
# Doc ID: doc_15682, Tweet ID: 1362845243398324226, Score: 3.0740797078150073
# Content: India’s farmers and landless workers toil in the fields to feed the nation, but they are given no say in the decisions that impact their livelihood and survival.             REPEAL THESE DICTATOR LAWS NOW !!  #FarmersProtest #kisanektazindabad https://t.co/2qQFNRDiN8
#
# Doc ID: doc_18822, Tweet ID: 1362492547910823939, Score: 3.0740797078150073
# Content: Farmers are the backbone of society. Their work not only ensures we have food to eat, it also impacts everything from the environment to the economy. #FarmersProtest
# https://t.co/GsC0cyFudI

# %% [markdown]
# ## **Ranking with Our Score + Cosine Similarity**

# %%
#tweets[0]

# %%
def calculate_normalized_popularity(tweets, weight_likes=1.0, weight_retweets=1.5, weight_comments=0.5, weight_quotes=0.5, weight_followers_count=0.0001):

    raw_popularity_scores = {}
    max_popularity = 0

    for tweet in tweets:
        popularity_score = (
            weight_likes * tweet['likeCount'] +
            weight_retweets * tweet['retweetCount'] +
            weight_comments * tweet['replyCount'] +
            weight_quotes * tweet['quoteCount'] +
            weight_followers_count * tweet['user']['followersCount']
        )

        if 'verified' in tweet and tweet['verified'] == 'True':
            popularity_score += 10000 #weighs the same as 10k likes or 10M followers, fair

        raw_popularity_scores[tweet['id']] = popularity_score
        max_popularity = max(max_popularity, popularity_score) #get max popularity to normalize

    #normalizing
    normalized_popularity_scores = {tweet_id: ((raw_score / max_popularity)*4 if max_popularity > 0 else 0) for tweet_id, raw_score in raw_popularity_scores.items()}

    return normalized_popularity_scores

# %%
# Step 2: Update calculate_combined_scores to use precomputed popularity scores
def calculate_combined_scores(query, tweets, inv_index_tfidf, idf, tf, docs, normalized_popularity_scores):
    results, scores = rank_documents(query, docs, inv_index_tfidf, idf, tf)

    combined_scores = []
    for doc in results:
        tweet_id = doc_to_tweet_map.get(doc)
        tweet = next(t for t in tweets if t['id'] == tweet_id)

        # Retrieve normalized popularity score
        normalized_popularity = normalized_popularity_scores.get(tweet_id, 0)

        # Retrieve cosine similarity score
        cosine_similarity_score = next((score for score, d in scores if d == doc), 0)

        # Combine the scores with equal weighting
        combined_score = 0.4 * normalized_popularity + 0.6 * cosine_similarity_score
        combined_scores.append((tweet_id, combined_score, cosine_similarity_score))

    # Sort tweets by combined score in descending order
    combined_scores.sort(reverse=True, key=lambda x: x[1])

    # Return the top-ranked tweets with combined scores
    return combined_scores

# %%
#compute normalized popularity scores for all tweets
normalized_popularity_scores = calculate_normalized_popularity(tweets)

# %%
#normalized_popularity_scores

# %%
for query in test_queries:

    ranked_tweets = calculate_combined_scores(query, tweets, inv_index_tfidf, idf, tf, docs, normalized_popularity_scores)

    # Display the top 10 ranked tweets for each query
    print(f"Top tweets for query '{query}':\n")
    i=1
    for tweet_id, score, cosine_score in ranked_tweets[:20]:

        print("\n")
        print(i)
        tweet = next(t for t in tweets if t['id'] == tweet_id)

        print(f"Tweet ID: {tweet_id}, Combined Score: {score}, Popularity Score: {normalized_popularity_scores[tweet_id]}, TF-IDF Cosine Score: {cosine_score}")
        print(f"Content: {tweet['content']}")
        print(f"Likes: {tweet['likeCount']}, Retweets: {tweet['retweetCount']}, Replies: {tweet['replyCount']}, Quotes: {tweet['quoteCount']}, Followers: {tweet['user']['followersCount']}")
        if 'verified' in tweet:
          print(f"Verified: {tweet['verified']}\n")
        else:
          print(f"Verified: False\n")

        i+=1
# Out:
# Top tweets for query 'Who supports indian law':
#
#
#
# 1
# Tweet ID: 1361724205709066247, Combined Score: 1.6411360453961839, Popularity Score: 0.004754819722160552, TF-IDF Cosine Score: 2.7320568625121995
# Content: Indian farmers are protesting new laws that will allow corporations to drive down the prices at which farmers sell produce. In return, they’re facing severe govt repression
# @mujerxsrising just put out a video in support of the #FarmersProtest—please watch:
# https://t.co/PWrkVKY4Nc
# Likes: 19, Retweets: 15, Replies: 2, Quotes: 1, Followers: 20157
# Verified: False
#
#
#
# 2
# Tweet ID: 1364110026361745411, Combined Score: 1.6397202666299686, Popularity Score: 0.0012153728066223155, TF-IDF Cosine Score: 2.7320568625121995
# Content: Just curious... how much money does the Indian govt have to keep paying people to show up in support of BJP? How many "farmers" have you already paid to say farm laws are good? Didnt know India had a budget for this🤡🤡 #FarmersProtest #Pagdi_Sambhal_Jatta #FarmersProtests https://t.co/KZ7jiXzAYA
# Likes: 4, Retweets: 5, Replies: 0, Quotes: 0, Followers: 64
# Verified: False
#
#
#
# 3
# Tweet ID: 1363348220445925378, Combined Score: 1.63952110705492, Popularity Score: 0.0007174738690000992, TF-IDF Cosine Score: 2.7320568625122
# Content: 87 farmer organisations and food justice groups in the United States delivered a solidarity statement in support of Indian farmers' protests against the new farm laws.
#
# #FarmersProtest https://t.co/PYklCc7xUI
# Likes: 2, Retweets: 1, Replies: 1, Quotes: 0, Followers: 27926
# Verified: False
#
#
#
# 4
# Tweet ID: 1363994816162455559, Combined Score: 1.6394494927565388, Popularity Score: 0.0005384381230478617, TF-IDF Cosine Score: 2.7320568625121995
# Content: Indian farmers protest is an ongoing protest against three farm acts which were passed by the Parliament of India in Sept 2020. Farmer unions and their reps have demanded that the laws be repealed and have stated that they will not accept a compromise support #FarmersProtest
# Likes: 2, Retweets: 2, Replies: 0, Quotes: 0, Followers: 976
# Verified: False
#
#
#
# 5
# Tweet ID: 1363624819636469769, Combined Score: 1.6393820612401873, Popularity Score: 0.0003698593321689408, TF-IDF Cosine Score: 2.7320568625121995
# Content: Thank you @ABC, US farmer unions.
# Thank you for supporting the farmers protesting the draconian laws forced upon Indian farmers
# #FarmersProtests #farmersprotest #MSPLawForAllCrops #NoFarmersNoFood https://t.co/oOweacZlGl
# Likes: 2, Retweets: 1, Replies: 0, Quotes: 0, Followers: 16
# Verified: False
#
#
#
# 6
# Tweet ID: 1360042595729121281, Combined Score: 1.639339967242856, Popularity Score: 0.0002646243388402009, TF-IDF Cosine Score: 2.7320568625121995
# Content: Indian farmers have been on the road since November last year, seeking repeal of three new farm laws and demanding minimum support prices for their produce.
# We need Mahapanchayats to poke the sleeping pseudo-nationalists.
# #MahapanchayatRevolution
# #FarmersProtest
# Likes: 1, Retweets: 1, Replies: 0, Quotes: 0, Followers: 53
# Verified: False
#
#
#
# 7
# Tweet ID: 1364130568808595456, Combined Score: 1.6393397559912382, Popularity Score: 0.00026409620979609403, TF-IDF Cosine Score: 2.7320568625121995
# Content: We can be proud of Ajit Singh Ji and the #FarmersProtest in 1907 whilst also supporting a peaceful and pragmatic end to the current protest.
#
# Remember, the Indian Supreme Court has already intervened:
# - Laws on hold
# - Offer to mediate
#
# #Pagdi_Sambhal_Jatta https://t.co/SpDD7gM4lZ
# Likes: 1, Retweets: 1, Replies: 0, Quotes: 0, Followers: 3
# Verified: False
#
#
#
# 8
# Tweet ID: 1363837054052933632, Combined Score: 1.6393186899799268, Popularity Score: 0.0002114311815177544, TF-IDF Cosine Score: 2.7320568625121995
# Content: The Indian government is lying to the people by giving the #FarmersProtest a separatist spin because it's easier to gain support that way than to admit that these laws will be beneficial to private entities looking to expand in agriculture due to the economies of scale (6/6)
# Likes: 2, Retweets: 0, Replies: 0, Quotes: 0, Followers: 17
# Verified: False
#
#
#
# 9
# Tweet ID: 1361790334934470663, Combined Score: 1.6392985661508301, Popularity Score: 0.00016112160877613157, TF-IDF Cosine Score: 2.7320568625121995
# Content: Disha Ravi, co-founder of @FFFIndia, was arrested and charged with sedition for editing a Toolkit on how to support the #FarmersProtest.  A 2016 report by @hrw found that the Indian government has been using the broadly-defined sedition law to squash dissent. https://t.co/rTlAn2hOrM
# Likes: 1, Retweets: 0, Replies: 1, Quotes: 0, Followers: 254
# Verified: False
#
#
#
# 10
# Tweet ID: 1362992216130670593, Combined Score: 1.6392975563680978, Popularity Score: 0.00015859715194530062, TF-IDF Cosine Score: 2.7320568625121995
# Content: #DPstopIntimidatingFarmers
#
# Intimidation is the Indian government unwritten #toolkit circulated to DP against the law of this land and #StandWithDishaRavi who is another victim of supporting #FarmersProtest
# Likes: 0, Retweets: 1, Replies: 0, Quotes: 0, Followers: 15
# Verified: False
#
#
#
# 11
# Tweet ID: 1363444730474885128, Combined Score: 1.639240391680364, Popularity Score: 1.5685432609974786e-05, TF-IDF Cosine Score: 2.7320568625122
# Content: @MEAIndia @DrSJaishankar Will you also be shooting off an angry letter to the 87 America farmers union supporting Indian's farmers in their struggle against the corporate-benefiting black laws?
#
# https://t.co/atc5QCaUNH
#
# #FarmersProtest #MSPLawForAllCrops
# Likes: 0, Retweets: 0, Replies: 0, Quotes: 0, Followers: 1485
# Verified: False
#
#
#
# 12
# Tweet ID: 1361839799120797699, Combined Score: 1.6392344132595844, Popularity Score: 7.393806617496532e-07, TF-IDF Cosine Score: 2.7320568625121995
# Content: @BernieSanders Grassroots support of democracy is so important. Indian farmers r facing devastatingly corrupt neoliberal farm laws. while peacefully protesting Modi gov is inflicting gross #HumanRightsViolations. Danger to democracy in one country is danger everywhere. #FarmersProtest https://t.co/JmOWt7lhMw
# Likes: 0, Retweets: 0, Replies: 0, Quotes: 0, Followers: 70
# Verified: False
#
#
#
# 13
# Tweet ID: 1360125250378362882, Combined Score: 1.6392341259573844, Popularity Score: 2.1125161764275807e-08, TF-IDF Cosine Score: 2.7320568625121995
# Content: @Cristiano @Cristiano plz support farmers protest which is going on in India Delhi against farm laws Indian media is not covering the protest. They r spreading negativity only about protest #FarmersProtest https://t.co/Tm6tj9Pw4I
# Likes: 0, Retweets: 0, Replies: 0, Quotes: 0, Followers: 2
# Verified: False
#
#
#
# 14
# Tweet ID: 1360532532446392320, Combined Score: 1.5652200446091546, Popularity Score: 0.00010583706043902179, TF-IDF Cosine Score: 2.6086295163082984
# Content: In support of ongoing farmers protest against black laws imposed by indian government, we are meeting at Sandringham park to share our thoughts and there will be aerial display in the Auckland sky with slogan
# support indian farmer #FarmersProtest
# from 2.30pm to 4.30pm
# Likes: 1, Retweets: 0, Replies: 0, Quotes: 0, Followers: 20
# Verified: False
#
#
#
# 15
# Tweet ID: 1360169174178222084, Combined Score: 1.553395915851942, Popularity Score: 0.00026589184854605745, TF-IDF Cosine Score: 2.588815931854206
# Content: So if Rihanna tweets in support of the farmers, Indian cricketers/actors will tweet that our sovereignty is under attack but if US govt says they support the Farm laws, they stay silent. It is clear that they are just pawns of propaganda for the Modi government #FarmersProtest https://t.co/tL6G6AVRWc
# Likes: 1, Retweets: 1, Replies: 0, Quotes: 0, Followers: 173
# Verified: False
#
#
#
# 16
# Tweet ID: 1361559428063977473, Combined Score: 1.5532353364780938, Popularity Score: 0.00022810949673065018, TF-IDF Cosine Score: 2.5885734877990028
# Content: #FarmersProtests
# Milk &amp; food: Indian villages support protesting farmers
#
# Small villages around #Delhi are supporting the tens of thousands of farmers encamped around the capital as they demand the repeal of new agriculture laws
#
# https://t.co/w6FBVG8hJI #FarmLaws #FarmersProtest https://t.co/72duGMYiBy
# Likes: 1, Retweets: 0, Replies: 1, Quotes: 1, Followers: 1596
# Verified: False
#
#
#
# 17
# Tweet ID: 1363670184372932608, Combined Score: 1.5484132830672597, Popularity Score: 0.00068674732121396, TF-IDF Cosine Score: 2.5802309735646234
# Content: 60% of Indian Population either directly or indirectly support #FarmersProtest to repeal Kisan Laws to make a Reform Laws for incorporating MSP in 23 crops limiting stocking.
# Is not #ModiIgnoringFarmersDeaths &amp; focusing only in WB, Assam, TM, Kerala, Puduchery elections ? Now https://t.co/4cBNKv15jJ
# Likes: 3, Retweets: 2, Replies: 1, Quotes: 0, Followers: 17
# Verified: False
#
#
#
# 18
# Tweet ID: 1363673852627288066, Combined Score: 1.548265521010783, Popularity Score: 0.00031734218002295116, TF-IDF Cosine Score: 2.580230973564623
# Content: 60% Indian either directly or indirectly supporting #FarmersProtest for repealing Kisan Laws to make Kisan Reform Law for incorporating MSP in 23 crops limiting stocking.
#
# Is not #ModiIgnoringFarmersDeaths &amp; focusing only in WB, Assam, TN, Kerala, Puduchery elections ? Now united https://t.co/4Nhpl0RSMx
# Likes: 1, Retweets: 1, Replies: 1, Quotes: 0, Followers: 44
# Verified: False
#
#
#
# 19
# Tweet ID: 1363678305690546177, Combined Score: 1.5482443958490186, Popularity Score: 0.00026452927561226164, TF-IDF Cosine Score: 2.580230973564623
# Content: @news24tvchannel @Tejasvi_Surya 60% Indian supporting #FarmersProtest for repealing Kisan Laws to make Kisan Reform Law for incorporating MSP in 23 crops limiting stocking.
#
# Is not #ModiIgnoringFarmersDeaths &amp; focusing only in WB, Assam, TN, Kerala, Puduchery elections ? Now united
# #TamilNadu #BJP #DMK #DMK4TN https://t.co/87pkFKOdNZ
# Likes: 1, Retweets: 1, Replies: 0, Quotes: 0, Followers: 44
# Verified: False
#
#
#
# 20
# Tweet ID: 1363729863987847169, Combined Score: 1.5481809062878524, Popularity Score: 0.00010580537269637538, TF-IDF Cosine Score: 2.580230973564623
# Content: 60% Indian Kisan supporting #FarmersProtest for repealing Kisan Laws to make Kisan Reform Law for incorporating MSP in 23 crops limiting stocks.
#
# Is not #ModiIgnoringFarmersDeaths &amp; focusing only in WB, Assam, TN, Kerala, Puduchery ?
# What next when Modi Ji in Election only ? https://t.co/NOzDREtvRw
# Likes: 1, Retweets: 0, Replies: 0, Quotes: 0, Followers: 17
# Verified: False
#
# Top tweets for query 'Impact of government policies on farmers':
#
#
#
# 1
# Tweet ID: 1360773511699030018, Combined Score: 2.39284565183863, Popularity Score: 0.0002645504007740259, TF-IDF Cosine Score: 3.987899719463868
# Content: “One Size For All” for Policy resulted in disastrous #FarmLaws which has created huge impact on Indian Farmers , which resulted in #FarmersProtest ! They neither capable of understanding the problem not able to solve it. So we don’t need you here. #GoBackModiModi #GoBackModi https://t.co/2X0JpLeYSX
# Likes: 1, Retweets: 1, Replies: 0, Quotes: 0, Followers: 46
# Verified: False
#
#
#
# 2
# Tweet ID: 1364085008567201792, Combined Score: 2.0550478112700863, Popularity Score: 0.6109306366536211, TF-IDF Cosine Score: 3.0177925943477297
# Content: There's a #FarmersProtest in Germany where some farmers are not satisfied with the policies of the government. But we don't live in Germany, we live in India. We have the humility to say that we don't understand the issue as well as citizens of Germany do. Just saying.
# Likes: 4825, Retweets: 595, Replies: 95, Quotes: 25, Followers: 64144
# Verified: False
#
#
#
# 3
# Tweet ID: 1362089639662739462, Combined Score: 2.0517047670382422, Popularity Score: 0.00837218679686632, TF-IDF Cosine Score: 3.4139264871991597
# Content: Why are farmers protesting in India, how is the Indian government responding, and what is the impact of the #FarmersProtest around the world? Listen via @thecarolinadesi's latest podcast episode --&gt; https://t.co/bkjuCleFMX. Take action --&gt; https://t.co/wQt69t7gOe https://t.co/kGe8IjfRWU
# Likes: 49, Retweets: 17, Replies: 2, Quotes: 1, Followers: 32627
# Verified: False
#
#
#
# 4
# Tweet ID: 1360414819396976641, Combined Score: 2.0485266216518427, Popularity Score: 0.0004268233308663105, TF-IDF Cosine Score: 3.41392648719916
# Content: The Biden administration is not directly impacted by the farmer protests. However, the US Embassy in New Delhi issued a statement after the Indian government temporarily cut internet access at the protest sites in January.
# #FarmersProtest #RepealOnlyWayAhead
# Likes: 1, Retweets: 2, Replies: 0, Quotes: 0, Followers: 409
# Verified: False
#
#
#
# 5
# Tweet ID: 1360230381165957123, Combined Score: 2.048503802252106, Popularity Score: 0.0003697748315218837, TF-IDF Cosine Score: 3.4139264871991615
# Content: @Femi_Sorry The farmers protest is also suffering and these goons have showed zero support. India has violated international human rights laws openly and Boris and Priti have turned a blind eye. Even with @amnesty speaking up, it has no impact on this UK government. #farmersprotest #BLM https://t.co/Cj94xHZJnP
# Likes: 2, Retweets: 1, Replies: 0, Quotes: 0, Followers: 8
# Verified: False
#
#
#
# 6
# Tweet ID: 1363702031287013376, Combined Score: 2.014227915351281, Popularity Score: 0.0003736829864482747, TF-IDF Cosine Score: 3.356797403594503
# Content: @CNN
# @GLOBALNEWS
# @nytimes
# @CBCNews
# @BBCNews
# 250 Indian farmers died in protests
# Deliberate attempt by Government to ignore farmers rights, &amp; devastating impact of these laws  on livelihoods of millions in India.
# #ModiIgnoringFarmersDeaths
# #RepealFarmLaws
# #FarmersProtest https://t.co/PGEw9p9W7R
# Likes: 2, Retweets: 1, Replies: 0, Quotes: 0, Followers: 378
# Verified: False
#
#
#
# 7
# Tweet ID: 1362964455076753408, Combined Score: 2.0141774438272715, Popularity Score: 0.0001593999080923431, TF-IDF Cosine Score: 3.3568561397733907
# Content: @meenaharris This suits Indian people these days. Farmers,activists, poor citizens, everyone who owns a motor vehicle, women, young girls, older farmers, younger men who are labourers or farmers who are being impacted everyday by the Godi Government should say #ThisSucks
# #FarmersProtest
# Likes: 0, Retweets: 1, Replies: 0, Quotes: 0, Followers: 91
# Verified: False
#
#
#
# 8
# Tweet ID: 1362264249490411520, Combined Score: 2.0125122612303974, Popularity Score: 0.009947352796076898, TF-IDF Cosine Score: 3.3475555335199445
# Content: The Punjab elections that happened were town/city level. This wasn’t an election that would have an impact on the central government. I’m reading about upcoming elections. I know MP pushed theirs (not sure if it was state or town level), (con’t)
# #FarmersProtest
# Likes: 61, Retweets: 19, Replies: 1, Quotes: 2, Followers: 31754
# Verified: False
#
#
#
# 9
# Tweet ID: 1360660763061354496, Combined Score: 1.9061791483323929, Popularity Score: 0.00015855490162177208, TF-IDF Cosine Score: 3.176859543952907
# Content: @AJEYA21 @amandeepskoutl1 @open__age A. No governance by the government - MSP and legal methods to recoup losses B. Full market control by corporate power houses - they will determine prices based on customer demand and their ability to store produce. C. No competition - impact price #FarmersProtest
# Likes: 1, Retweets: 0, Replies: 1, Quotes: 0, Followers: 11
# Verified: False
#
#
#
# 10
# Tweet ID: 1362227632037888000, Combined Score: 1.863929964321967, Popularity Score: 0.04870534908240549, TF-IDF Cosine Score: 3.0740797078150077
# Content: Original Reporting | BJP Routed In Punjab Municipal Elections As #FarmersProtest Impacts Electoral Fortunes, from @amaanbali
#
# “We never voted during municipal elections but this time I told my sons and daughters to vote for the sake of farmers."
#
# https://t.co/GtgJeUn6bE
# Likes: 334, Retweets: 80, Replies: 5, Quotes: 8, Followers: 6122
# Verified: False
#
#
#
# 11
# Tweet ID: 1363768903055237125, Combined Score: 1.8604842307365304, Popularity Score: 0.04009101511881616, TF-IDF Cosine Score: 3.074079707815007
# Content: For anyone who is wondering why farmers are protesting in Delhi, this well-reported story by @parthpunter describes the devastating impact of similar farming reforms elsewhere in India #FarmersProtest https://t.co/zsTrrADGLq
# Likes: 248, Retweets: 84, Replies: 4, Quotes: 4, Followers: 15570
# Verified: False
#
#
#
# 12
# Tweet ID: 1363118084828012546, Combined Score: 1.8565865750155366, Popularity Score: 0.030346875816330714, TF-IDF Cosine Score: 3.0740797078150073
# Content: The first image is the way farmers ensured public is not impacted during rail roko &amp; 2nd is BJP goons  rail roko. #FarmersProtest @INCIndia @srivatsayb @Pawankhera https://t.co/6JnLGoZiFs
# Likes: 126, Retweets: 107, Replies: 0, Quotes: 1, Followers: 3055
# Verified: False
#
#
#
# 13
# Tweet ID: 1361396126327345156, Combined Score: 1.8465540286670963, Popularity Score: 0.005265509945231037, TF-IDF Cosine Score: 3.074079707815007
# Content: The Premier’s letter to the PM to convey the deep concern that thousands of British Columbians have for the farmers in protest in India.  Thinking of those families impacted by this &amp; worried for their loved ones. #farmersprotest https://t.co/UXaS6v3BvP
# Likes: 40, Retweets: 6, Replies: 0, Quotes: 1, Followers: 3506
# Verified: False
#
#
#
# 14
# Tweet ID: 1362845243398324226, Combined Score: 1.8449364327804827, Popularity Score: 0.00122152022869572, TF-IDF Cosine Score: 3.0740797078150073
# Content: India’s farmers and landless workers toil in the fields to feed the nation, but they are given no say in the decisions that impact their livelihood and survival.             REPEAL THESE DICTATOR LAWS NOW !!  #FarmersProtest #kisanektazindabad https://t.co/2qQFNRDiN8
# Likes: 8, Retweets: 2, Replies: 0, Quotes: 1, Followers: 646
# Verified: False
#
#
#
# 15
# Tweet ID: 1363951260211179520, Combined Score: 1.8447873018135235, Popularity Score: 0.0008486928112988985, TF-IDF Cosine Score: 3.074079707815007
# Content: For anyone who is Wondering why Farmers are Protesting in Delhi, this Well Reported Story by @parthpunter describes the devastating impact of Similar Farming Reforms elsewhere in India
#
# #FarmersProtest
#
# https://t.co/4Es0Lornyy
# Likes: 3, Retweets: 3, Replies: 1, Quotes: 0, Followers: 349
# Verified: False
#
#
#
# 16
# Tweet ID: 1360709114897268742, Combined Score: 1.8447023828882638, Popularity Score: 0.0006363954981488087, TF-IDF Cosine Score: 3.0740797078150073
# Content: @jimmykimmel @jimmykimmel please raise your voice against the injustices happening in India in the largest peaceful protest! Please support our farmers! This will impact the entire world ! 🥺 #FarmersProtest
# Likes: 3, Retweets: 2, Replies: 0, Quotes: 0, Followers: 250
# Verified: False
#
#
#
# 17
# Tweet ID: 1362297542776483841, Combined Score: 1.8446610029214001, Popularity Score: 0.0005329455809891501, TF-IDF Cosine Score: 3.0740797078150073
# Content: Questions to PM Modi:
#
# How do you turn your back on our countries farmers &amp; act like everything is fine?
#
# How do you sleep peacefully at night knowing that the farm bill will impact many poor #farmers livelihood?
#
# Many endless questions...
#
# #FarmersProtest
# #RailRokoForFarmers https://t.co/3Qq6zOqx5W
# Likes: 5, Retweets: 0, Replies: 0, Quotes: 0, Followers: 456
# Verified: False
#
#
#
# 18
# Tweet ID: 1364475355038437378, Combined Score: 1.8446606733688766, Popularity Score: 0.0005321216996803433, TF-IDF Cosine Score: 3.0740797078150077
# Content: The farmers are much more learned and aware of the impact of the three Black laws than the govt tries to portray.
#
# #FarmersProtest
# #ModiDontSellFarmers
# #modi_rojgaar_do https://t.co/xQTHKispY3
# Likes: 2, Retweets: 2, Replies: 0, Quotes: 0, Followers: 378
# Verified: False
#
#
#
# 19
# Tweet ID: 1360502301790621699, Combined Score: 1.8446379891701743, Popularity Score: 0.00047541120292414485, TF-IDF Cosine Score: 3.0740797078150077
# Content: Bihar scrapped APMC Act, mandi system 14 years ago.
#
# Govt doesn’t give guaranteed MSP
# So allowing corporate to exploit to the max
#
# NO FINANCIAL PROTECTION
# NO LEGAL PROTECTION
#
# This will impact future of farmer &amp;consumers
#
# #RepealOnlyWayAhead
# #FarmersProtest https://t.co/LzmwOFcgB3
# Likes: 2, Retweets: 1, Replies: 1, Quotes: 1, Followers: 9
# Verified: False
#
#
#
# 20
# Tweet ID: 1360423196898570241, Combined Score: 1.8446225889272478, Popularity Score: 0.00043691059560875225, TF-IDF Cosine Score: 3.0740797078150073
# Content: The impact of the farmers' protest in India is likely to effect Bollywood in many ways. We explore why:
#
# https://t.co/58y30ut7Ul
#
# #bollywood #FarmersProtest #farmersrprotest #Indian
# #film #businessgrowth
# Likes: 2, Retweets: 1, Replies: 0, Quotes: 0, Followers: 6364
# Verified: False

# %% [markdown]
# ## **Ranking with BM25**

# %%
k1 = 1.2
b = 0.75

def calculate_avg_doc_length(tf):
    """
    Calcula la longitud promedio de los documentos.
    """
    doc_lengths = defaultdict(int)
    for term, postings in tf.items():
        for i, freq in enumerate(postings):
            doc_lengths[i] += freq
    total_length = sum(doc_lengths.values())
    num_docs = len(doc_lengths)
    return total_length / num_docs

def bm25_score(query, docs, index, idf, tf, avg_doc_length):
    """
    Calcula el ranking BM25 para una consulta dada.

    Parameters:
    - query: La cadena de la consulta.
    - docs: Lista de documentos a considerar.
    - index: Índice invertido con términos mapeados a postings de documentos.
    - idf: Diccionario con los valores de IDF.
    - tf: Diccionario con las frecuencias de los términos en los documentos.
    - avg_doc_length: Longitud promedio de los documentos en la colección.

    Returns:
    - Lista de documentos ordenados por puntuación BM25.
    """
    query_terms = build_terms(query)
    doc_scores = defaultdict(float)

    for term in query_terms:
        if term in index:
            idf_term = idf.get(term, 0)
            for doc_idx, (doc, postings) in enumerate(index[term]):
                if doc in docs:
                    f_q_d = tf[term][doc_idx]  # Frecuencia de término en el documento
                    doc_length = len(postings)
                    score = idf_term * ((f_q_d * (k1 + 1)) / (f_q_d + k1 * (1 - b + b * (doc_length / avg_doc_length))))
                    doc_scores[doc] += score

    # Ordenar los documentos por puntaje en orden descendente
    return sorted(doc_scores.items(), key=lambda x: x[1], reverse=True)

# %%
# Calculate the average document length
avg_doc_length = calculate_avg_doc_length(tf)

# Iterate over each test query for BM25
for query in test_queries:
    bm25_results = bm25_score(query, docs, inv_index_tfidf, idf, tf, avg_doc_length)

    print(f"Ranking for query '{query}':\n")

    for doc, score in bm25_results[:20]:  # Iterate over the top 20 results
        tweet_id = doc_to_tweet_map.get(doc, "Unknown")  # Get the tweet_id corresponding to the doc_id
        # Find the content of the tweet corresponding to the document ID
        tweet_content = next((tweet['content'] for tweet in tweets if tweet['id'] == tweet_id), "No content available")

        print(f"Doc ID: {doc}, Tweet ID: {tweet_id}, Score: {score}")
        print(f"Content: {tweet_content}\n")

    print("\n")
# Out:
# #FarmersProtest https://t.co/CG7JyMh8Sq
#
# Doc ID: doc_7237, Tweet ID: 1363702031287013376, Score: 6.0132690729744205
# Content: @CNN
# @GLOBALNEWS
# @nytimes
# @CBCNews
# @BBCNews
# 250 Indian farmers died in protests
# Deliberate attempt by Government to ignore farmers rights, &amp; devastating impact of these laws  on livelihoods of millions in India.
# #ModiIgnoringFarmersDeaths
# #RepealFarmLaws
# #FarmersProtest https://t.co/PGEw9p9W7R
#
# Doc ID: doc_27992, Tweet ID: 1361713332584022018, Score: 5.992081566860177
# Content: Thank You @aaww, @mujerxsrising &amp; all other fellow Organizations to raise issue of Indian Farmers.
#
# We are hopeful our Peaceful #FarmersProtest will be helpful to bring positive change in our Government policy on Farmers. https://t.co/n2xFYAytCj
#
# Doc ID: doc_43710, Tweet ID: 1360414819396976641, Score: 5.980854567050165
# Content: The Biden administration is not directly impacted by the farmer protests. However, the US Embassy in New Delhi issued a statement after the Indian government temporarily cut internet access at the protest sites in January.
# #FarmersProtest #RepealOnlyWayAhead
#
# Doc ID: doc_24983, Tweet ID: 1361907077770190856, Score: 5.955248957753425
# Content: Government's cheap policies can't stop us to take Our Rights
# We will Fight We Will win..
# 120
# #FarmersMakelndia
# #FarmersProtest https://t.co/UzQo4G3DU8
#
# Doc ID: doc_24984, Tweet ID: 1361907063601864705, Score: 5.955248957753425
# Content: Government's cheap policies can't stop us to take Our Rights
# We will Fight We Will win..
# 119
# #FarmersMakelndia
# #FarmersProtest https://t.co/k5kYPbUzn3
#
# Doc ID: doc_24986, Tweet ID: 1361906874530979844, Score: 5.955248957753425
# Content: Government's cheap policies can't stop us to take Our Rights
# We will Fight We Will win..
# 118
# #FarmersMakelndia
# #FarmersProtest https://t.co/m3tMhfic7g
#
# Doc ID: doc_24988, Tweet ID: 1361906838669717505, Score: 5.955248957753425
# Content: Government's cheap policies can't stop us to take Our Rights
# We will Fight We Will win..
# 117
# #FarmersMakelndia
# #FarmersProtest https://t.co/z7wbhUxvh7
#
# Doc ID: doc_24989, Tweet ID: 1361906793517969410, Score: 5.955248957753425
# Content: Government's cheap policies can't stop us to take Our Rights
# We will Fight We Will win..
# 116
# #FarmersMakelndia
# #FarmersProtest https://t.co/i3rEvDZKoq
#
# Doc ID: doc_24991, Tweet ID: 1361906729949175816, Score: 5.955248957753425
# Content: Government's cheap policies can't stop us to take Our Rights
# We will Fight We Will win..
# 115
# #FarmersMakelndia
# #FarmersProtest https://t.co/PBC1QnvcOu
#
# Doc ID: doc_24993, Tweet ID: 1361906609224491011, Score: 5.955248957753425
# Content: Government's cheap policies can't stop us to take Our Rights
# We will Fight We Will win..
# 114
# #FarmersMakelndia
# #FarmersProtest https://t.co/5XWddCmGks

# %% [markdown]
# ## **Similarity between rankings of TF-IDF and BM25**

# %%
# Compare the top 20 results of each query for TF-IDF and BM25 and identify common documents
for query in test_queries:
    # Get the top 20 results for both TF-IDF and BM25
    tfidf_results, _ = rank_documents(query, docs, inv_index_tfidf, idf, tf)
    bm25_results = bm25_score(query, docs, inv_index_tfidf, idf, tf, avg_doc_length)

    # Extract document IDs
    tfidf_docs = {doc for doc in tfidf_results[:20]}
    bm25_docs = {doc for doc, _ in bm25_results[:20]}

    # Find the common document IDs
    common_docs = tfidf_docs.intersection(bm25_docs)

    # Print comparison results
    print(f"Query '{query}':")
    print(f"Number of common documents: {len(common_docs)}")
    if common_docs:
        print("Common document IDs:")
        for doc_id in common_docs:
            print(f"Doc ID: {doc_id}, Tweet Content: {next((tweet['content'] for tweet in tweets if tweet['id'] == doc_to_tweet_map.get(doc_id)), 'No content available')}")
    else:
        print("No common documents found.")
    print("\n")
# Out:
# Query 'Who supports indian law':
# Number of common documents: 4
# Common document IDs:
# Doc ID: doc_42274, Tweet Content: In support of ongoing farmers protest against black laws imposed by indian government, we are meeting at Sandringham park to share our thoughts and there will be aerial display in the Auckland sky with slogan
# support indian farmer #FarmersProtest
# from 2.30pm to 4.30pm
# Doc ID: doc_10497, Tweet Content: 87 farmer organisations and food justice groups in the United States delivered a solidarity statement in support of Indian farmers' protests against the new farm laws.
#
# #FarmersProtest https://t.co/PYklCc7xUI
# Doc ID: doc_9681, Tweet Content: @MEAIndia @DrSJaishankar Will you also be shooting off an angry letter to the 87 America farmers union supporting Indian's farmers in their struggle against the corporate-benefiting black laws?
#
# https://t.co/atc5QCaUNH
#
# #FarmersProtest #MSPLawForAllCrops
# Doc ID: doc_13857, Tweet Content: #DPstopIntimidatingFarmers
#
# Intimidation is the Indian government unwritten #toolkit circulated to DP against the law of this land and #StandWithDishaRavi who is another victim of supporting #FarmersProtest
#
#
# Query 'Impact of government policies on farmers':
# Number of common documents: 4
# Common document IDs:
# Doc ID: doc_7237, Tweet Content: @CNN
# @GLOBALNEWS
# @nytimes
# @CBCNews
# @BBCNews
# 250 Indian farmers died in protests
# Deliberate attempt by Government to ignore farmers rights, &amp; devastating impact of these laws  on livelihoods of millions in India.
# #ModiIgnoringFarmersDeaths
# #RepealFarmLaws
# #FarmersProtest https://t.co/PGEw9p9W7R
# Doc ID: doc_43710, Tweet Content: The Biden administration is not directly impacted by the farmer protests. However, the US Embassy in New Delhi issued a statement after the Indian government temporarily cut internet access at the protest sites in January.
# #FarmersProtest #RepealOnlyWayAhead
# Doc ID: doc_39522, Tweet Content: “One Size For All” for Policy resulted in disastrous #FarmLaws which has created huge impact on Indian Farmers , which resulted in #FarmersProtest ! They neither capable of understanding the problem not able to solve it. So we don’t need you here. #GoBackModiModi #GoBackModi https://t.co/2X0JpLeYSX
# Doc ID: doc_23037, Tweet Content: Why are farmers protesting in India, how is the Indian government responding, and what is the impact of the #FarmersProtest around the world? Listen via @thecarolinadesi's latest podcast episode --&gt; https://t.co/bkjuCleFMX. Take action --&gt; https://t.co/wQt69t7gOe https://t.co/kGe8IjfRWU

# %% [markdown]
# # **2. WORD-2-VEC + COSINE SIMILARITY**

# %%
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
#now we are using 5 queries
test_queries = ["Who supports indian law",
                "Impact of government policies on farmers",
                "Who is breaking in farmers' protest? ",
                "what is the real issue? ",
                "who is against indian farmers"]

# %% [markdown]
# ## **Word2Vec model**

# %%
# Tokenize each tweet's content
tweet_tokens = [build_terms(tweet['content']) for tweet in tweets]

# We create the Word2Vec model on tokenized tweets
model = Word2Vec(sentences=tweet_tokens, vector_size=300, window=5, min_count=1, workers=4)

# %% [markdown]
# ## **Tweet2Vec**

# %%
#Function to create the vector representation of a tweet
def tweet2vec(tweet, model):
    tokens = build_terms(tweet)  # We use the build_terms function to process the tweet
    vectors = [model.wv[token] for token in tokens if token in model.wv]  # Only use tokens present in Word2Vec vocabulary
    if len(vectors) == 0:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# %%
tweetVec = {tweet['id']: tweet2vec(tweet['content'], model) for tweet in tweets}

# %% [markdown]
# ## **Ranking with Cosine Similarity**

# %%
def rank_documents_word2vec(query, tweetVec, model, top_k=20):
    query_vector = tweet2vec(query, model)  # To represent the query as a vector
    similarities = []

    # Compute cosine similarity
    for tweet_id, doc_vector in tweetVec.items():
        score = cosine_similarity([query_vector], [doc_vector])[0][0]
        similarities.append((score, tweet_id))

    # Sort by similarity score in descending order and retunr the top 20 results
    similarities.sort(reverse=True, key=lambda x: x[0])
    return similarities[:top_k]

# %%
# Iterate over each query and print the top 20 ranked documents with scores, document IDs, and content using Word2Vec
for query in test_queries:
    ranked_tweets = rank_documents_word2vec(query, tweetVec, model, top_k=20)

    print(f"Top 20 documents for query '{query}':\n")
    for rank, (score, tweet_id) in enumerate(ranked_tweets, start=1):
        # Find the doc_id using the tweet_id
        doc_id = next((doc for doc, tweet in doc_to_tweet_map.items() if tweet == tweet_id), "Unknown")
        tweet_content = next((tweet['content'] for tweet in tweets if tweet['id'] == tweet_id), "No content available")

        print(f"Rank: {rank}")
        print(f"Doc ID: {doc_id}, Tweet ID: {tweet_id}, Score: {score}")
        print(f"Content: {tweet_content}\n")
# Out:
# Top 20 documents for query 'Who supports indian law':
#
# Rank: 1
# Doc ID: doc_6913, Tweet ID: 1363727092332957697, Score: 0.9671066999435425
# Content: San Francisco supporting the Indian Farmers Protest, Indian govt should take back the 3 laws @amarg408 @ANI #ModiIgnoringFarmersDeath #farmersprotest https://t.co/vr88iZ8qSQ
#
# Rank: 2
# Doc ID: doc_42274, Tweet ID: 1360532532446392320, Score: 0.9629135131835938
# Content: In support of ongoing farmers protest against black laws imposed by indian government, we are meeting at Sandringham park to share our thoughts and there will be aerial display in the Auckland sky with slogan
# support indian farmer #FarmersProtest
# from 2.30pm to 4.30pm
#
# Rank: 3
# Doc ID: doc_47424, Tweet ID: 1360077710517694465, Score: 0.9624799489974976
# Content: The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide demonstrations against three recently introduced farm laws..
#
# #MahapanchayatRevolution
#
# #FarmersProtest https://t.co/nt7C0jmzXn
#
# Rank: 4
# Doc ID: doc_47060, Tweet ID: 1360093634171985920, Score: 0.9610351920127869
# Content: Do you support the #FarmersProtest and their call for a repeal of Modi's new agricultural laws?
#
# Rank: 5
# Doc ID: doc_30304, Tweet ID: 1361528434011344897, Score: 0.9609026312828064
# Content: The Indian government will do everything &amp; anything they can BUT repeal the farm laws. #FarmersProtest
#
# Rank: 6
#
# Rank: 16
# Doc ID: doc_17695, Tweet ID: 1362614451636084743, Score: 0.9586515426635742
# Content: #ReleaseDetainedFarmers
# Farmers Protesting  have been arrested by Indian Govt for fake charges
#
# Release all detained farmers &amp; their supportersFolded handsFolded hands
#
# Govt:Withdraw the 3 black laws &amp; make law on MSP
# #FarmersProtest
# #StandWithFarmers #FarmerLivesMatter
#
# Rank: 17
# Doc ID: doc_18619, Tweet ID: 1362537288383614978, Score: 0.9581525325775146
# Content: Listen to @The_Red_Nation , buy the incredible new book by @HarshaWalia and support the Indian #FarmersProtest! https://t.co/YVLB2Ann0h
#
# Rank: 18
# Doc ID: doc_13266, Tweet ID: 1363030345621377026, Score: 0.9579322934150696
# Content: #DPstopIntimidatingFarmers
# #FarmersProtest                                             We want our rights, these laws are unconstitutional and serve only to help the ‘great reset’ repeal these laws and create better social/Agri laws that will help the masses.
#
# Rank: 19
# Doc ID: doc_41965, Tweet ID: 1360568711007059968, Score: 0.9575514793395996
# Content: The Indian government must immediately stop its escalating crackdown on farmers, activists&amp; journalists amid the ongoing demonstrations against 3 recently introduced farm laws.
# #Rose2Repeal #LoveToFarmers #OneAppealRepeal #FarmersProtest @UNHumanRights #GoBackModi @meenaharris https://t.co/qUlYbqLWVG
#
# Rank: 20
# Doc ID: doc_13857, Tweet ID: 1362992216130670593, Score: 0.9575212001800537
# Content: #DPstopIntimidatingFarmers
#
# Intimidation is the Indian government unwritten #toolkit circulated to DP against the law of this land and #StandWithDishaRavi who is another victim of supporting #FarmersProtest
#
# Top 20 documents for query 'Impact of government policies on farmers':
#
# Rank: 1
# Doc ID: doc_9261, Tweet ID: 1363502696326594561, Score: 0.980567216873169
# Content: In stead creating jobs for youths Modi government inclined todestroy farmer sector to make farmers slave. Modi government shd realise that farmers are not only self dependent but also a huge creator of jobs for others. Repeal farmers black laws.
#
# #modi_rojgar_do
# #FarmersProtest
#
# Rank: 2
# Doc ID: doc_29130, Tweet ID: 1361619561674637320, Score: 0.9803498983383179
# Content: It is saddened for Indian government to be so cruel and nasty playing these kind of tactics to suppress farmers voice...#FarmersProtest #farmerslivesmatter https://t.co/owGsUMQkui
#
# Rank: 3
# Doc ID: doc_42816, Tweet ID: 1360487707571441669, Score: 0.9790354371070862
# Content: #RepealOnlyWayAhead Farmers fear the exploitation from private sector as govt has not given any safety net to the farmers from  greed of the private companies. #FarmersProtest
#
# Rank: 4
# Doc ID: doc_35146, Tweet ID: 1361140394780725259, Score: 0.9782878160476685
# Content: I can’t believe how ignorant a democratic government can be these farmers have been on the road for Months and government still doesn’t have no solution #FarmersProtest
#
# Rank: 5
# Doc ID: doc_1096, Tweet ID: 1364404740218576896, Score: 0.9770026206970215
# Content: @CorruptPunjab Thing is that if farmers don’t wants that law why you’re government forces them to have a where’s your so called democracy ✌️#Farmersprotest
#
# Rank: 6
# Doc ID: doc_6846, Tweet ID: 1363732780740272134, Score: 0.976879894733429
# Content: 254 farmers lost their lives
# Modi government is silent
# 25+ farmers are missing
# government is not responding.
# 100+ farmers are being sued
# Content: Media outlets are constantly seeking a range of voices to discuss issues such as the #FarmersProtest. If you are approached to discuss it, or if you are in a demographic that is not often platformed regarding such issues, we are here to help with advice and more. Get in touch!
#
# Rank: 10
# Doc ID: doc_28612, Tweet ID: 1361662685918683143, Score: 0.9853581786155701
# Content: @ClaudiaWebbe Hello! Pls DO NOT interfere in other countries matters, if u don’t know ABC of #FarmersProtest. It’s a trend these days. Criminals get associated with something the world is emotional about &amp; morons like this MP will jump in support of such criminals, as if they really care.
#
# Rank: 11
# Doc ID: doc_39341, Tweet ID: 1360789761875730432, Score: 0.9853411912918091
# Content: Your privilege and ignorance really shows when u say people who support #FarmersProtest dont know what theyre talking about. They sure as hell do, they just also happen to have a conscience and arent politically brainwashed
#
# Rank: 12
# Doc ID: doc_45121, Tweet ID: 1360261439143825411, Score: 0.9853038191795349
# Content: @RamNanduri @GretaThunberg Read this article very carefully. https://t.co/3Ddm5FJX6C
# As a consumer in India one should be aware of the fact that monopoly in a few hand with result in financial pressure on the middle and lower classes due to rising costs. Support #FarmersProtest #iamwithfarmer
#
# Rank: 13
# Doc ID: doc_25742, Tweet ID: 1361882118603816962, Score: 0.9852558970451355
# Content: It’s great to see @PremierScottMoe focusing on real issues that are affecting our Canadian lives. Unlike the #liberals whose MPs &amp; MLAs are still busy pleasing their vote banks. Indian #FarmersProtest is a prime example. Wake up #canada, this time vote wisely #Conservatives #sk https://t.co/0JKDivQl5N
#
# Rank: 14
# Doc ID: doc_46160, Tweet ID: 1360167340600655874, Score: 0.9849326610565186
# Content: The same stance should have raised by the #Sikh leaders of 🇵🇰. It is difficult to comprehend the reason behind their silence on such significant issues. People like Gopal Chawla who are vocal about #FarmersProtest  should have also taken up such issues into consideration
# @SikhPA https://t.co/t24Miq1XGf
#
# Rank: 15
# Doc ID: doc_3481, Tweet ID: 1364120894419832835, Score: 0.9849083423614502
# Content: At any given point in time
# one must focus on #onecauseatatime
# Somehow I feel #IndianMedia is more interested in selling stories than telling stories
#
# #FarmersProtest has been biggest story but as always media gets distracted
# I never planned to be a #gamechanger or a #worldchanger
#
# Rank: 16
# Doc ID: doc_3379, Tweet ID: 1364131219550728192, Score: 0.9848451018333435
# Content: @sachin_rt @imVkohli You should have done the same thing first know know about  #FarmersProtest ,talk to them &amp; don’t spread propaganda against them. Now i think you have realized the value of MSP(demanding by #Farmers) also because you got that in IPL auction. #StandWithFarmers
#
# Rank: 17
# Doc ID: doc_26, Tweet ID: 1364502520412930049, Score: 0.984822154045105
# Content: @mkinthuk @amaanbali Some strange phenomenon is happening. Every post I look at related to the #farmersprotest, I see a stupid comment like this one! I read somewhere that the BJP IT cell is in overdrive mode and is trying their hardest to defame the farmers movement, is it true??
#
# Rank: 18
# Doc ID: doc_34348, Tweet ID: 1361181903911596032, Score: 0.984750509262085
# Content: Because they have nothing else to do, these ppl @DelhiPolice are going to now try to find an angle to defame the protests from the outside. DON'T GIVE THEM THAT CHANCE!
# #FarmersProtest
#
# Rank: 19
# Doc ID: doc_42659, Tweet ID: 1360501464293081088, Score: 0.9847250580787659
# Content: @Annette21908627 @banga_kb Gandhi protested for years to get what he wanted. #FarmersProtest is nothing new which India hasn’t seen before.The new thing is IT cell and #GodiMedia maligning it!
#
# It’s like a dumb student writing a film story and pretending to know everyone but a teacher catches him out!!
#
# Rank: 20
# Doc ID: doc_40226, Tweet ID: 1360698488460365825, Score: 0.9846317768096924
# Content: @munawar0018 Very well said @munawar0018, public on internet does not abuse or hate you, it is a propaganda of people related to a certain "cell", I think u also know that. From now on I will watch each 'n every of ur videos online. More power to u.
#
# Will keep supporting #FarmersProtest
#
# Top 20 documents for query 'who is against indian farmers':
#
# Rank: 1
# Doc ID: doc_44653, Tweet ID: 1360292444454191110, Score: 0.9765818119049072
# Content: Thinking about Indian farmers today  and Indian farmers only. #FarmersProtest https://t.co/ZLVwhCLCOo
#
# Rank: 2
# Doc ID: doc_23662, Tweet ID: 1362029313269366790, Score: 0.9627199769020081
# Content: Pay attention Indian farmers. #FarmersProtest @Devinder_Sharma https://t.co/TuSb6ZCHrB
#
# Rank: 3
# Doc ID: doc_22487, Tweet ID: 1362155203449917441, Score: 0.9623532891273499
# Content: Why Is @mabrouq Is Silent About #FarmersProtest. Here's Full Thread About Indian Farmers &amp; Maldivian Government ⬇️ https://t.co/x6uBtA5Kqs
#
# Rank: 4
# Doc ID: doc_39501, Tweet ID: 1360776208896516097, Score: 0.9619554877281189
# Content: It's ironical that Indian media and government labelling our Farmers as terrorists ; but most of the sons of our Farmers are indian soldiers!!
#
# Govt. is  Disrespecting our FARMERS and SOLDIERS !! Shame!!
#
# #शहीद_जवान_शहीद_किसान
# #FarmersProtest https://t.co/MEn3u08IR5
#
# Rank: 5
# Doc ID: doc_7799, Tweet ID: 1363674149357453315, Score: 0.9612906575202942
# Content: Farmers are neglecting by Indian detatorail govt
# #ModiIgnoringFamersDeaths
# #FarmersProtest https://t.co/xOk9Uwp31T
#
# Rank: 6
# Doc ID: doc_47380, Tweet ID: 1360080448211152896, Score: 0.9605008959770203
# Content: @Wendys Could you roast the Indian government for its treatment of farmers in the #FarmersProtest ? https://t.co/iKxZ85LOsJ
#
# Rank: 7
# Doc ID: doc_18901, Tweet ID: 1362481164246687744, Score: 0.9592961072921753
# Content: #FarmersProtest resonanted pan-india today?🤔
#
# Kitne farmers the?🤔
#
# Please don't tarnished the image of majority of Indian farmers not in this protest..👍😀😏
#
# #OriginalChatukarChamcaGodiMedia👇 will do their propaganda &amp; false,fake narrative setting..😂😂 https://t.co/yi5yHc4uwl
#
# Rank: 8
# Doc ID: doc_3199, Tweet ID: 1364149086576807939, Score: 0.9587420225143433
# Content: @dhruv_rathee Not a farmer
# No fOd
# Not a farmer
# No greenery
# Not a farmer
# Not haPiness
# Not a farmer
# Not healthy
# Not a farmer
# No Humans and animals
# Not a farmer
# No employment,business,economy
# Not a farmer
# No progreS of the nation
# If not farmer
# Is the country not even the land
# #FarmersProtest
#
# Rank: 9
# Doc ID: doc_8345, Tweet ID: 1363606923929657345, Score: 0.9585211277008057
# Content: @ZMAHMOO2 indian farmers zinda bad
#
# #FarmersProtest
#
# Rank: 10
